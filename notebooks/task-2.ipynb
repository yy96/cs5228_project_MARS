# %% [markdown]
# # Task 2: Recommendation Engine

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ### Load the Data

# %%
df = pd.read_csv('../data/train.csv')
df.head()
# Out:
#    listing_id                                   title           make   model  \
# 0     1030324  BMW 3 Series 320i Gran Turismo M-Sport            bmw    320i
# 1     1021510                       Toyota Hiace 3.0M            NaN   hiace
# 2     1026909          Mercedes-Benz CLA-Class CLA180  mercedes-benz  cla180
# 3     1019371   Mercedes-Benz E-Class E180 Avantgarde  mercedes-benz    e180
# 4     1031014                    Honda Civic 1.6A VTi            NaN   civic
#
#                                          description  manufactured  \
# 0  1 owner! 320i gt m-sports model! big brake kit...        2013.0
# 1  high loan available! low mileage unit. wear an...        2014.0
# 2  1 owner c&c unit. full agent service with 1 mo...        2016.0
# 3  fully agent maintained, 3 years warranty 10 ye...        2019.0
# 4  kah motor unit! 1 owner, lowest 1.98% for full...        2019.0
#
#   original_reg_date     reg_date  type_of_vehicle  \
# 0               NaN  09-dec-2013     luxury sedan
# 1               NaN  26-jan-2015              van
# 2               NaN  25-jul-2016     luxury sedan
# 3               NaN  17-nov-2020     luxury sedan
# 4               NaN  20-sep-2019  mid-sized sedan
#
#                                     category  ...   mileage      omv      arf  \
# 0  parf car, premium ad car, low mileage car  ...   73000.0  45330.0  50462.0
# 1                             premium ad car  ...  110112.0  27502.0   1376.0
# 2                   parf car, premium ad car  ...   80000.0  27886.0  26041.0
# 3  parf car, almost new car, consignment car  ...    9800.0  46412.0  56977.0
# 4                                   parf car  ...   40000.0  20072.0  20101.0
#
#   opc_scheme     lifespan   eco_category  \
# 0        NaN          NaN  uncategorized
# 1        NaN  25-jan-2035  uncategorized
# 2        NaN          NaN  uncategorized
# 3        NaN          NaN  uncategorized
# 4        NaN          NaN  uncategorized
#
#                                             features  \
# 0  5 doors gt, powerful and fuel efficient 2.0l t...
# 1  low mileage unit. well maintained vehicle. vie...
# 2  responsive and fuel efficient 1.6l inline 4 cy...
# 3  1.5l inline-4 twin scroll turbocharged engine,...
# 4  1.6l i-vtec engine, 123 bhp, earth dreams cvt ...
#
#                                          accessories  indicative_price  \
# 0  bmw i-drive, navigation, bluetooth/aux/usb inp...               NaN
# 1  factory radio setting. front recording camera....               NaN
# 2  dual electric/memory seats. factory fitted aud...               NaN
# 3  64 colour ambient lighting. active parking ass...               NaN
# 4  s/rims, premium leather seats, factory touch s...               NaN
#
#       price
# 0   71300.0
# 1   43800.0
# 2   95500.0
# 3  197900.0
# 4  103200.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Approach: Content based model using Item-Item similarities

# %% [markdown]
# ### Preprocessing

# %%
# Mapping of listing id to array index
listing_id_to_idx, index_to_listing_id = {}, {}
listing_ids = df["listing_id"].unique()

for idx, listing_id in enumerate(listing_ids):
    listing_id_to_idx[listing_id] = idx
    index_to_listing_id[idx] = listing_id

# %%
# Processing numerical data
numerical_features = ["manufactured", "mileage", "price", "curb_weight", "power", "engine_cap", "no_of_owners"]
cars_num_features = np.array(df[numerical_features].fillna(-1))

# Processing text data
text_features = ['transmission','category','description','type_of_vehicle','accessories']

def combine_features(row):
        combined = [str(row[feature]) for feature in text_features]
        combined = " ".join(combined)
        return combined

df["combined_features"] = df.apply(combine_features,axis=1)
cv = CountVectorizer() 
count_matrix = cv.fit_transform(df["combined_features"])

# %%
# Calculate cosine similarity

# Numerical features
num_features_cosine_similarities = cosine_similarity(cars_num_features, cars_num_features)

# Text features using the count vectorizer
text_features_cosine_similarities = cosine_similarity(count_matrix, count_matrix)

# Create an aggregated cosine similarity matrix
w1 = 1
w2 = 1
combined_cosine_similarities = w1 * num_features_cosine_similarities + w2 * text_features_cosine_similarities

# %%
def get_top_recommendations_item_item(row, **kwargs) -> pd.DataFrame:
    
    #####################################################
    ## Initialize the required parameters
    
    # The number of recommendations seem recommended
    # Additional input parameters are up to you
    k = None
    
    # Extract all **kwargs input parameters
    # and set the used paramaters (here: k)
    for key, value in kwargs.items():
        if key == 'k':
            k = value
            
    #####################################################
    ## Compute your recommendations
    
    listing_index = listing_id_to_idx[row["listing_id"]]
    listing_similarities = combined_cosine_similarities[listing_index]
    listing_similarities[listing_index] = -1 # we don't want to select the same listing
    listing_top_k_similarity = np.argpartition(listing_similarities, -k)[-k:]
    listing_top_k_similarity_sorted = np.flip(listing_top_k_similarity[np.argsort(listing_similarities[listing_top_k_similarity])])
    df_result= df.iloc[listing_top_k_similarity_sorted]
        
    # Return the dataset with the k recommendations
    return df_result

# %% [markdown]
# ### Testing

# %%
row_id = 5
row = df.iloc[row_id]

k = 5
pd.DataFrame([row])
# Out:
#    listing_id                                              title  \
# 5     1027957  Mercedes-Benz A-Class A35 AMG 4MATIC Premium Plus
#
#             make model                                        description  \
# 5  mercedes-benz   a35  one and only a35 with a45 features in sg! bidd...
#
#    manufactured original_reg_date  reg_date type_of_vehicle  \
# 5           NaN       25-dec-2020       NaN      sports car
#
#                          category  ...      omv  arf  opc_scheme  lifespan  \
# 5  imported used vehicle, coe car  ...  34000.0  NaN         NaN       NaN
#
#     eco_category                                           features  \
# 5  uncategorized  powered by a newly developed 2 litre four cyli...
#
#                                          accessories  indicative_price  \
# 5  fitted with amg aero package, amg performance ...               NaN
#
#       price                                  combined_features
# 5  273800.0  auto imported used vehicle, coe car one and on...
#
# [1 rows x 31 columns]

# %%
df_recommendations = get_top_recommendations_item_item(row, k=k)
df_recommendations.head(k)
# Out:
#        listing_id                                              title  \
# 16533      995076                    Mercedes-Benz C-Class C63 S AMG
# 3872       985686  Mercedes-Benz GLE-Class GLE43 Coupe AMG 4MATIC...
# 6398       999458    BMW M Series M4 Convertible Competition Package
# 300        997405          BMW M Series M4 Coupe Competition Package
# 12150     1025352                          BMW 5 Series 530i M-Sport
#
#                 make model                                        description  \
# 16533  mercedes-benz   amg  unbeatable price with c63 s model! with a bran...
# 3872   mercedes-benz   amg  unbeatable price with gle43 coupe amg night ed...
# 6398             bmw    m4  unbeatable price with m4 convertible competiti...
# 300              bmw    m4  unbeatable price with m4 coupe competition pac...
# 12150            bmw  530i  unbeatable price with bmw 530i m-sport! with a...
#
#        manufactured original_reg_date     reg_date type_of_vehicle  \
# 16533           NaN       06-mar-2019          NaN      sports car
# 3872            NaN       04-jun-2019          NaN             suv
# 6398         2018.0       18-jun-2018  16-jun-2021      sports car
# 300             NaN       25-sep-2019          NaN      sports car
# 12150           NaN       26-sep-2018          NaN    luxury sedan
#
#                                               category  ...      omv      arf  \
# 16533    imported used vehicle, coe car, rare & exotic  ...  70000.0      NaN
# 3872                    imported used vehicle, coe car  ...  50000.0      NaN
# 6398   imported used vehicle, parf car, almost new car  ...  42780.0  51892.0
# 300                     imported used vehicle, coe car  ...  50000.0      NaN
# 12150                   imported used vehicle, coe car  ...  24000.0      NaN
#
#        opc_scheme lifespan   eco_category  \
# 16533         NaN      NaN  uncategorized
# 3872          NaN      NaN  uncategorized
# 6398          NaN      NaN  uncategorized
# 300           NaN      NaN  uncategorized
# 12150         NaN      NaN  uncategorized
#
#                                                 features  \
# 16533  powerful 4.0l v8 twin-turbocharged pushing 503...
# 3872   3.0l v6 bi-turbo engine at 385bhp/520nm. 9g-tr...
# 6398   bmw m twin power turbo inline 6 cylinder petro...
# 300    bmw m twin power turbo inline 6 cylinder petro...
# 12150  powerful 2.0l turbo charged engine,8 speed ste...
#
#                                              accessories  indicative_price  \
# 16533  19" amg rims, amg sports seats, amg brakes, am...               NaN
# 3872   paddle shift, adaptive damping, power tailgate...               NaN
# 6398   m competition package, original m-bodykits, ha...               NaN
# 300    m competition package, carbon fiber roof, orig...               NaN
# 12150  leather seats, 19" m sports rims, audio system...               NaN
#
#           price                                  combined_features
# 16533  438800.0  auto imported used vehicle, coe car, rare & ex...
# 3872   317800.0  auto imported used vehicle, coe car unbeatable...
# 6398   328800.0  auto imported used vehicle, parf car, almost n...
# 300    339800.0  auto imported used vehicle, coe car unbeatable...
# 12150  218800.0  auto imported used vehicle, coe car unbeatable...
#
# [5 rows x 31 columns]
